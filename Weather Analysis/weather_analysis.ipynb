# %%
import pandas as pd
import numpy as np

# %%
#Reading files

df = pd.read_csv(r"C:\Users\User\Desktop\Data Analyst\Jupyter Notebook\Weather Analysis\weather.csv")
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# ### Exploring Data

# %%
df.shape

#finding: 8784 rows and 8 columns
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df["Weather"].nunique()
# Out:
# 50

# %%
df.count()    #good, no null values
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#renaming columns before EDA start

df.rename(columns = {
    "Date/Time": "date_time",
    "Temp_C":"temp(C)",
    "Dew Point Temp_C":"edw_point_temp(C)",
    "Rel Hum_%":"rel_hum(%)",
    "Wind Speed_km/h":"wind_speed(km/h)",
    "Visibility_km":"visibility(km)",
    "Press_kPa":"pressure(kPa)",
    "Weather":"weather"
}, inplace = True)

df.head()
# Out:
#        date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  wind_speed(km/h)  \
# 0  1/1/2012 0:00     -1.8               -3.9          86                 4
# 1  1/1/2012 1:00     -1.8               -3.7          87                 4
# 2  1/1/2012 2:00     -1.8               -3.4          89                 7
# 3  1/1/2012 3:00     -1.5               -3.2          88                 6
# 4  1/1/2012 4:00     -1.5               -3.3          88                 7
#
#    visibility(km)  pressure(kPa)               weather
# 0             8.0         101.24                   Fog
# 1             8.0         101.24                   Fog
# 2             4.0         101.26  Freezing Drizzle,Fog
# 3             4.0         101.27  Freezing Drizzle,Fog
# 4             4.8         101.23                   Fog

# %% [markdown]
# ### Questions and Answer

# %% [markdown]
# ##### 1. Find all the unqiue 'Wind Speed' values in the data

# %%
df["wind_speed(km/h)"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# ##### 2. Find the number of times when the "Wheather is exactly clear"

# %%
# using value_counts
df["weather"].value_counts()
# Out:
# weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# using filtering method
df[df["weather"] == "Clear"]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 67      1/3/2012 19:00    -16.9              -24.8          50
# 114     1/5/2012 18:00     -7.1              -14.4          56
# 115     1/5/2012 19:00     -9.2              -15.4          61
# 116     1/5/2012 20:00     -9.8              -15.7          62
# 117     1/5/2012 21:00     -9.0              -14.8          63
# ...                ...      ...                ...         ...
# 8646   12/26/2012 6:00    -13.4              -14.8          89
# 8698  12/28/2012 10:00     -6.1               -8.6          82
# 8713   12/29/2012 1:00    -11.9              -13.6          87
# 8714   12/29/2012 2:00    -11.8              -13.1          90
# 8756  12/30/2012 20:00    -13.8              -16.5          80
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa) weather
# 67                  24            25.0         101.74   Clear
# 114                 11            25.0         100.71   Clear
# ...

# %%
# groupby method
df.groupby("weather").get_group("Clear")
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 67      1/3/2012 19:00    -16.9              -24.8          50
# 114     1/5/2012 18:00     -7.1              -14.4          56
# 115     1/5/2012 19:00     -9.2              -15.4          61
# 116     1/5/2012 20:00     -9.8              -15.7          62
# 117     1/5/2012 21:00     -9.0              -14.8          63
# ...                ...      ...                ...         ...
# 8646   12/26/2012 6:00    -13.4              -14.8          89
# 8698  12/28/2012 10:00     -6.1               -8.6          82
# 8713   12/29/2012 1:00    -11.9              -13.6          87
# 8714   12/29/2012 2:00    -11.8              -13.1          90
# 8756  12/30/2012 20:00    -13.8              -16.5          80
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa) weather
# 67                  24            25.0         101.74   Clear
# 114                 11            25.0         100.71   Clear
# ...

# %% [markdown]
# ##### 3. Find the number of times when the 'Wind Speed was exactly '4 km/h'

# %%
# using filter method
df[df["wind_speed(km/h)"] == 4]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 0        1/1/2012 0:00     -1.8               -3.9          86
# 1        1/1/2012 1:00     -1.8               -3.7          87
# 96       1/5/2012 0:00     -8.8              -11.7          79
# 101      1/5/2012 5:00     -7.0               -9.5          82
# 146      1/7/2012 2:00     -8.1              -11.1          79
# ...                ...      ...                ...         ...
# 8768   12/31/2012 8:00     -8.6              -10.3          87
# 8769   12/31/2012 9:00     -8.1               -9.6          89
# 8770  12/31/2012 10:00     -7.4               -8.9          89
# 8772  12/31/2012 12:00     -5.8               -7.5          88
# 8773  12/31/2012 13:00     -4.6               -6.6          86
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa)       weather
# 0                    4             8.0         101.24           Fog
# 1                    4             8.0         101.24           Fog
# ...

# %% [markdown]
# ##### 4. Find out all the Null Values in the data

# %%
df.isnull().sum()
# Out:
# date_time            0
# temp(C)              0
# edw_point_temp(C)    0
# rel_hum(%)           0
# wind_speed(km/h)     0
# visibility(km)       0
# pressure(kPa)        0
# weather              0
# dtype: int64

# %% [markdown]
# ##### 5. What is the mean 'Visibility'?

# %%
df["visibility(km)"].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ##### 6. What is the STD of 'Pressure' in this data?

# %%
df["pressure(kPa)"].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ##### 7. What is the relative variance of the 'Relative humidity' in this data?

# %%
df.head()
# Out:
#        date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  wind_speed(km/h)  \
# 0  1/1/2012 0:00     -1.8               -3.9          86                 4
# 1  1/1/2012 1:00     -1.8               -3.7          87                 4
# 2  1/1/2012 2:00     -1.8               -3.4          89                 7
# 3  1/1/2012 3:00     -1.5               -3.2          88                 6
# 4  1/1/2012 4:00     -1.5               -3.3          88                 7
#
#    visibility(km)  pressure(kPa)               weather
# 0             8.0         101.24                   Fog
# 1             8.0         101.24                   Fog
# 2             4.0         101.26  Freezing Drizzle,Fog
# 3             4.0         101.27  Freezing Drizzle,Fog
# 4             4.8         101.23                   Fog

# %%
df["rel_hum(%)"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ##### 8. Find all instance when 'Snow' was recorded

# %%
df[df["weather"] == "Snow"]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 55       1/3/2012 7:00    -14.0              -19.5          63
# 84      1/4/2012 12:00    -13.7              -21.7          51
# 86      1/4/2012 14:00    -11.3              -19.0          53
# 87      1/4/2012 15:00    -10.2              -16.3          61
# 88      1/4/2012 16:00     -9.4              -15.5          61
# ...                ...      ...                ...         ...
# 8779  12/31/2012 19:00      0.1               -2.7          81
# 8780  12/31/2012 20:00      0.2               -2.4          83
# 8781  12/31/2012 21:00     -0.5               -1.5          93
# 8782  12/31/2012 22:00     -0.2               -1.8          89
# 8783  12/31/2012 23:00      0.0               -2.1          86
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa) weather
# 55                  19            25.0         100.95    Snow
# 84                  11            24.1         101.25    Snow
# ...

# %%
#using str containts method

df[df["weather"].str.contains("Snow")]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 41      1/2/2012 17:00     -2.1               -9.5          57
# 44      1/2/2012 20:00     -5.6              -13.4          54
# 45      1/2/2012 21:00     -5.8              -12.8          58
# 47      1/2/2012 23:00     -7.4              -14.1          59
# 48       1/3/2012 0:00     -9.0              -16.0          57
# ...                ...      ...                ...         ...
# 8779  12/31/2012 19:00      0.1               -2.7          81
# 8780  12/31/2012 20:00      0.2               -2.4          83
# 8781  12/31/2012 21:00     -0.5               -1.5          93
# 8782  12/31/2012 22:00     -0.2               -1.8          89
# 8783  12/31/2012 23:00      0.0               -2.1          86
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa)       weather
# 41                  22            25.0          99.66  Snow Showers
# 44                  24            25.0         100.07  Snow Showers
# ...

# %% [markdown]
# ##### 9. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25

# %%
df[(df["wind_speed(km/h)"] > 24) & (df["visibility(km)"] == 25)]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 23      1/1/2012 23:00      5.3                2.0          79
# 24       1/2/2012 0:00      5.2                1.5          77
# 25       1/2/2012 1:00      4.6                0.0          72
# 26       1/2/2012 2:00      3.9               -0.9          71
# 27       1/2/2012 3:00      3.7               -1.5          69
# ...                ...      ...                ...         ...
# 8705  12/28/2012 17:00     -8.6              -12.0          76
# 8753  12/30/2012 17:00    -12.1              -15.8          74
# 8755  12/30/2012 19:00    -13.4              -16.5          77
# 8759  12/30/2012 23:00    -12.1              -15.1          78
# 8760   12/31/2012 0:00    -11.1              -14.4          77
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa)        weather
# 23                  30            25.0          99.31         Cloudy
# 24                  35            25.0          99.26   Rain Showers
# ...

# %% [markdown]
# ##### 10. What is the Mean value of each colum againts each'Weather Condition'?

# %%
df.select_dtypes(include="number").groupby(df["weather"]).mean()
# Out:
#                                            temp(C)  edw_point_temp(C)  \
# weather
# Clear                                     6.825716           0.089367
# Cloudy                                    7.970544           2.375810
# Drizzle                                   7.353659           5.504878
# Drizzle,Fog                               8.067500           7.033750
# Drizzle,Ice Pellets,Fog                   0.400000          -0.700000
# Drizzle,Snow                              1.050000           0.150000
# Drizzle,Snow,Fog                          0.693333           0.120000
# Fog                                       4.303333           3.159333
# Freezing Drizzle                         -5.657143          -8.000000
# Freezing Drizzle,Fog                     -2.533333          -4.183333
# Freezing Drizzle,Haze                    -5.433333          -8.000000
# Freezing Drizzle,Snow                    -5.109091          -7.072727
# ...

# %% [markdown]
# ##### 11. What is the minimum and maximum value of each column againts each 'Wheather condition"?

# %%
df.select_dtypes(include="number").groupby(df["weather"]).max()
# Out:
#                                          temp(C)  edw_point_temp(C)  \
# weather
# Clear                                       32.8               20.4
# Cloudy                                      30.5               22.6
# Drizzle                                     18.8               17.7
# Drizzle,Fog                                 19.9               19.1
# Drizzle,Ice Pellets,Fog                      0.4               -0.7
# Drizzle,Snow                                 1.2                0.2
# Drizzle,Snow,Fog                             1.1                0.6
# Fog                                         20.8               19.6
# Freezing Drizzle                            -2.3               -3.3
# Freezing Drizzle,Fog                        -0.3               -2.3
# Freezing Drizzle,Haze                       -5.0               -7.7
# Freezing Drizzle,Snow                       -3.3               -4.6
# Freezing Fog                                -0.1               -0.3
# ...

# %%
df.select_dtypes(include="number").groupby(df["weather"]).min()
# Out:
#                                          temp(C)  edw_point_temp(C)  \
# weather
# Clear                                      -23.3              -28.5
# Cloudy                                     -21.4              -26.8
# Drizzle                                      1.1               -0.2
# Drizzle,Fog                                  0.0               -1.6
# Drizzle,Ice Pellets,Fog                      0.4               -0.7
# Drizzle,Snow                                 0.9                0.1
# Drizzle,Snow,Fog                             0.3               -0.1
# Fog                                        -16.0              -17.2
# Freezing Drizzle                            -9.0              -12.2
# Freezing Drizzle,Fog                        -6.4               -9.0
# Freezing Drizzle,Haze                       -5.8               -8.3
# Freezing Drizzle,Snow                       -8.3              -10.4
# Freezing Fog                               -19.0              -22.9
# ...

# %% [markdown]
# ##### 12. Show all the records whre weather is fog

# %%
df[df["weather"] == "Fog"]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 0        1/1/2012 0:00     -1.8               -3.9          86
# 1        1/1/2012 1:00     -1.8               -3.7          87
# 4        1/1/2012 4:00     -1.5               -3.3          88
# 5        1/1/2012 5:00     -1.4               -3.3          87
# 6        1/1/2012 6:00     -1.5               -3.1          89
# ...                ...      ...                ...         ...
# 8716   12/29/2012 4:00    -16.0              -17.2          90
# 8717   12/29/2012 5:00    -14.8              -15.9          91
# 8718   12/29/2012 6:00    -13.8              -15.3          88
# 8719   12/29/2012 7:00    -14.8              -16.4          88
# 8722  12/29/2012 10:00    -12.0              -13.3          90
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa) weather
# 0                    4             8.0         101.24     Fog
# 1                    4             8.0         101.24     Fog
# ...

# %% [markdown]
# ##### 13. Find all instances when 'Weather is clear or visbility is above 40?

# %%
df[(df["weather"] == "Clear") | (df["visibility(km)"] > 40)]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 67      1/3/2012 19:00    -16.9              -24.8          50
# 106     1/5/2012 10:00     -6.0              -10.0          73
# 107     1/5/2012 11:00     -5.6              -10.2          70
# 108     1/5/2012 12:00     -4.7               -9.6          69
# 109     1/5/2012 13:00     -4.4               -9.7          66
# ...                ...      ...                ...         ...
# 8749  12/30/2012 13:00    -12.4              -16.2          73
# 8750  12/30/2012 14:00    -11.8              -16.1          70
# 8751  12/30/2012 15:00    -11.3              -15.6          70
# 8752  12/30/2012 16:00    -11.4              -15.5          72
# 8756  12/30/2012 20:00    -13.8              -16.5          80
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa)        weather
# 67                  24            25.0         101.74          Clear
# 106                 17            48.3         100.45   Mainly Clear
# ...

# %% [markdown]
# ##### 14. Find all instances when:

# %% [markdown]
# ###### a.  wheather is clear and reltive humidity is greater than 50

# %% [markdown]
# ###### OR

# %% [markdown]
# ###### b. Visibility is above 40

# %%
df[(df["weather"] == "Clear") & (df["rel_hum(%)"] > 50) | (df["visibility(km)"] > 40)]
# Out:
#              date_time  temp(C)  edw_point_temp(C)  rel_hum(%)  \
# 106     1/5/2012 10:00     -6.0              -10.0          73
# 107     1/5/2012 11:00     -5.6              -10.2          70
# 108     1/5/2012 12:00     -4.7               -9.6          69
# 109     1/5/2012 13:00     -4.4               -9.7          66
# 110     1/5/2012 14:00     -5.1              -10.7          65
# ...                ...      ...                ...         ...
# 8749  12/30/2012 13:00    -12.4              -16.2          73
# 8750  12/30/2012 14:00    -11.8              -16.1          70
# 8751  12/30/2012 15:00    -11.3              -15.6          70
# 8752  12/30/2012 16:00    -11.4              -15.5          72
# 8756  12/30/2012 20:00    -13.8              -16.5          80
#
#       wind_speed(km/h)  visibility(km)  pressure(kPa)        weather
# 106                 17            48.3         100.45   Mainly Clear
# 107                 22            48.3         100.41   Mainly Clear
# ...
