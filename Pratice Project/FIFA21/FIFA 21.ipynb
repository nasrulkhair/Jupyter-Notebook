# %% [markdown]
# # FIFA 21 ANALYSIS

# %%
import pandas as pd
import numpy as np
import re
#import seaborn as sns
pd.set_option('display.max_columns',80)
#pd.set_option('display.max_rows', 19000)

# %%
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Data Analyst\FIFA21\fifa21 raw data v2.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3512\1236762278.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Data Analyst\FIFA21\fifa21 raw data v2.csv")

# %%
df
# Out:
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df.shape
# Out:
# (18979, 77)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# ID                      0
# Name                    0
# LongName                0
# photoUrl                0
# playerUrl               0
# Nationality             0
# Age                     0
# ↓OVA                    0
# POT                     0
# Club                    0
# Contract                0
# Positions               0
# Height                  0
# Weight                  0
# Preferred Foot          0
# BOV                     0
# Best Position           0
# Joined                  0
# Loan Date End       17966
# Value                   0
# Wage                    0
# Release Clause          0
# Attacking               0
# Crossing                0
# Finishing               0
# Heading Accuracy        0
# Short Passing           0
# Volleys                 0
# Skill                   0
# Dribbling               0
# Curve                   0
# FK Accuracy             0
# Long Passing            0
# Ball Control            0
# Movement                0
# ...

# %%
fifa = df.copy()
fifa.head(2)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position     Joined Loan Date End    Value   Wage  \
# 0           Left   93            RW  01-Jul-04           NaN  €103.5M  €560K
# ...

# %%
fifa['Club'].dtypes
# Out:
# dtype('O')

# %%
fifa['Club'].unique()
# Out:
# array(['\n\n\n\nFC Barcelona', '\n\n\n\nJuventus',
#        '\n\n\n\nAtlético Madrid', '\n\n\n\nManchester City',
#        '\n\n\n\nParis Saint-Germain', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nLiverpool', '\n\n\n\nReal Madrid', '\n\n\n\nChelsea',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nInter', '\n\n\n\nNapoli',
#        '\n\n\n\nBorussia Dortmund', '\n\n\n\nManchester United',
#        '\n\n\n\nArsenal', '\n\n\n\nLazio', '\n\n\n\nLeicester City',
#        '\n\n\n\nBorussia Mönchengladbach', '\n\n\n\nReal Sociedad',
#        '\n\n\n\nAtalanta', '\n\n\n\nOlympique Lyonnais', '\n\n\n\nMilan',
#        '\n\n\n\nVillarreal CF', '\n\n\n\nRB Leipzig', '\n\n\n\nCagliari',
#        '\n\n\n\nAjax', '\n\n\n\nSL Benfica', '\n\n\n\nAS Monaco',
#        '\n\n\n\nWolverhampton Wanderers', '\n\n\n\nEverton',
#        '\n\n\n\nFiorentina', '\n\n\n\nFC Porto', '\n\n\n\nRC Celta',
#        '\n\n\n\nTorino', '\n\n\n\nSevilla FC', '\n\n\n\nGrêmio',
# ...

# %%
fifa['Club'] = fifa['Club'].str.split('\n\n\n\n').str.get(1)
fifa['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City',
#        'Paris Saint-Germain', 'FC Bayern München', 'Liverpool',
#        'Real Madrid', 'Chelsea', 'Tottenham Hotspur', 'Inter', 'Napoli',
#        'Borussia Dortmund', 'Manchester United', 'Arsenal', 'Lazio',
#        'Leicester City', 'Borussia Mönchengladbach', 'Real Sociedad',
#        'Atalanta', 'Olympique Lyonnais', 'Milan', 'Villarreal CF',
#        'RB Leipzig', 'Cagliari', 'Ajax', 'SL Benfica', 'AS Monaco',
#        'Wolverhampton Wanderers', 'Everton', 'Fiorentina', 'FC Porto',
#        'RC Celta', 'Torino', 'Sevilla FC', 'Grêmio', 'Real Betis', 'Roma',
#        'Newcastle United', 'Eintracht Frankfurt', 'Valencia CF',
#        'Medipol Başakşehir FK', 'Inter Miami', 'Bayer 04 Leverkusen',
#        'Levante UD', 'Crystal Palace', 'Athletic Club de Bilbao',
#        'Shanghai SIPG FC', 'VfL Wolfsburg',
#        'Guangzhou Evergrande Taobao FC', 'Al Shabab',
# ...

# %%
fifa['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
# Checking the 'loan' and 'free' - using for loop (iterrows())

for index, row in fifa.iterrows():
    if 'On Loan' in row['Contract'] or 'Free' in row['Contract']:
        print( row['Contract'])
# Out:
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Jan 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# ...

# %%
def extract_contract_info(contract):
    if contract == 'Free' or 'On Loan' in contract:
        start_date = np.nan
        end_date = np.nan
        contract_length = 0
    else:
        start_date, end_date = contract.split(' ~ ')
        start_year = int(start_date[:4])
        end_year = int(end_date[:4])
        contract_length = end_year - start_year
    return start_date, end_date, contract_length

# Apply function to Contract column & create new columns

new_cols = ['Contract Start', 'Contract End','Contract Length(years)']
new_data = fifa['Contract'].apply(lambda x: pd.Series(extract_contract_info(x)))

for i in range(len(new_cols)):
    fifa.insert(loc=fifa.columns.get_loc('Contract')+1+i, column = new_cols[i], value=new_data[i])

# %%
fifa.sample(3)
# Out:
#            ID          Name           LongName  \
# 483    185221  Luiz Gustavo  Luiz Gustavo Dias
# 15968  246713      K. Nkuba          Ken Nkuba
# 2589   223284   P. Martinez     Pablo Martinez
#
#                                                photoUrl  \
# 483    https://cdn.sofifa.com/players/185/221/21_60.png
# 15968  https://cdn.sofifa.com/players/246/713/21_60.png
# 2589   https://cdn.sofifa.com/players/223/284/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 483    http://sofifa.com/player/185221/luiz-gustavo-d...      Brazil   32
# 15968  http://sofifa.com/player/246713/ken-nkuba/210006/     Belgium   18
# 2589   http://sofifa.com/player/223284/pablo-martinez...      France   31
#
#        ↓OVA  POT                   Club     Contract Contract Start  \
# 483      80   80          Fenerbahçe SK  2019 ~ 2023           2019
# 15968    59   75  Sporting de Charleroi  2018 ~ 2021           2018
# ...

# %%
fifa[['Contract','Contract Start','Contract End', 'Contract Length(years)']].sample(5)
# Out:
#           Contract Contract Start Contract End  Contract Length(years)
# 13702  2019 ~ 2021           2019         2021                     2.0
# 18494  2020 ~ 2020           2020         2020                     0.0
# 2722   2019 ~ 2022           2019         2022                     3.0
# 17243  2018 ~ 2021           2018         2021                     3.0
# 7770          Free            NaN          NaN                     0.0

# %%
# Contract Categories

def categorize_contract_status(contract):   # define columns name and specifies which column is the input
    if 'Free' in contract:
        return 'Contract'
    elif 'On Loan' in contract:
        return 'On Loan'
    else:
        return 'Contract'

# Add contract status column
fifa.insert(fifa.columns.get_loc('Contract Length(years)')+1, 'Contract Status', fifa['Contract'].apply(categorize_contract_status))

# %%
fifa.sample(3)
# Out:
#            ID           Name           LongName  \
# 12430  244602    O. Boussaid    Othman Boussaid
# 18652  253943       R. Boyce        Ronan Boyce
# 807    206058  M. De Sciglio  Mattia De Sciglio
#
#                                                photoUrl  \
# 12430  https://cdn.sofifa.com/players/244/602/21_60.png
# 18652  https://cdn.sofifa.com/players/253/943/21_60.png
# 807    https://cdn.sofifa.com/players/206/058/21_60.png
#
#                                                playerUrl          Nationality  \
# 12430  http://sofifa.com/player/244602/othman-boussai...              Belgium
# 18652  http://sofifa.com/player/253943/ronan-boyce/21...  Republic of Ireland
# 807    http://sofifa.com/player/206058/mattia-de-scig...                Italy
#
#        Age  ↓OVA  POT                Club     Contract Contract Start  \
# 12430   20    63   74          FC Utrecht  2018 ~ 2021           2018
# 18652   19    51   64          Derry City  2019 ~ 2020           2019
# ...

# %%
fifa[['Contract','Contract Start','Contract End', 'Contract Length(years)','Contract Status']].sample(5)
# Out:
#           Contract Contract Start Contract End  Contract Length(years)  \
# 13543  2020 ~ 2021           2020         2021                     1.0
# 9622   2020 ~ 2023           2020         2023                     3.0
# 1896   2019 ~ 2023           2019         2023                     4.0
# 8124   2018 ~ 2020           2018         2020                     2.0
# 15039  2019 ~ 2023           2019         2023                     4.0
#
#       Contract Status
# 13543        Contract
# 9622         Contract
# 1896         Contract
# 8124         Contract
# 15039        Contract

# %%
# Converting Height nto cm
fifa['Height'].dtypes
# Out:
# dtype('O')

# %%
fifa['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
# Converting Height

def convert_height(height):
    if "cm" in height:
        return int(height.strip("cm"))
    else:
        feet, inches = height.split("'")
        total_inches = int(feet)*12 + int(inches.strip('"'))
        return round(total_inches * 2.54)

# Apply into the height column

fifa['Height'] = fifa['Height'].apply(convert_height)

# %%
fifa['Height'].unique()
# Out:
# array([170, 187, 188, 181, 175, 184, 191, 178, 193, 185, 199, 173, 168,
#        176, 177, 183, 180, 189, 179, 195, 172, 182, 186, 192, 165, 194,
#        167, 196, 163, 190, 174, 169, 171, 197, 200, 166, 164, 198, 201,
#        158, 162, 161, 160, 203, 157, 156, 202, 159, 206, 155], dtype=int64)

# %%
fifa = fifa.rename(columns = { "Height":"Height(cm)"})

# %%
fifa.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
# Adjusting Weight
fifa['Weight'].dtype
# Out:
# dtype('O')

# %%
fifa['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
def convert_weight(weight):
    if "kg" in weight:
        return int(weight.strip("kg"))
    else:
        pounds = int(weight.strip("lbs"))
        return round(pounds * 0.454)

# Apply into the weight column

fifa['Weight'] = fifa['Weight'].apply(convert_weight)

# %%
fifa['Weight'].unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52], dtype=int64)

# %%
fifa.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
fifa = fifa.rename(columns = {'Weight': 'Weight(kg)'})

# %%
fifa.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
# Date Loan Player End

fifa['Loan Date End'].unique()
# Out:
# array([nan, '30-Jun-21', '31-Dec-20', '30-Jan-21', '30-Jun-22',
#        '31-May-21', '05-Jul-21', '31-Dec-21', '01-Jul-21', '01-Jan-21',
#        '31-Aug-21', '31-Jan-21', '30-Dec-21', '23-Jun-21', '03-Jan-21',
#        '27-Nov-21', '17-Jan-21', '30-Jun-23', '31-Jul-21', '22-Nov-20',
#        '31-May-22', '30-Dec-20', '04-Jan-21', '30-Nov-20', '01-Aug-21'],
#       dtype=object)

# %%
on_loan = fifa[fifa['Contract Status'] == 'On Loan']

# %%
on_loan[['Name','Contract','Contract Status','Loan Date End']]
# Out:
#                  Name              Contract Contract Status Loan Date End
# 205           G. Bale  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 248         A. Areola  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 254    Danilo Pereira  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 302       M. Politano  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 306       L. Torreira  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# ...               ...                   ...             ...           ...
# 18472       M. Najjar  Aug 31, 2021 On Loan         On Loan     31-Aug-21
# 18571         A. Read  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 18600     Deng Yubiao  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18622         Chen Pu  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18680    Chen Zhechao  Dec 31, 2020 On Loan         On Loan     31-Dec-20
#
# [1013 rows x 4 columns]

# %%
# Player's Weak Foot rating (out of 5)
fifa.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Contract Start', 'Contract End',
#        'Contract Length(years)', 'Contract Status', 'Positions', 'Height(cm)',
#        'Weight(kg)', 'Preferred Foot', 'BOV', 'Best Position', 'Joined',
#        'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Attacking',
#        'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing',
#        'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility',
#        'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina',
#        'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions',
#        'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending',
#        'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping',
#        'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning',
# ...

# %%
fifa['W/F'].dtype
# Out:
# dtype('O')

# %%
fifa['W/F'].unique()
# Out:
# array(['4 ★', '3 ★', '5 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['W/F'] = fifa['W/F'].str.split(' ').str.get(0)

# %%
fifa['W/F'] = fifa['W/F'].astype(int)

# %%
fifa['W/F'].dtypes
# Out:
# dtype('int32')

# %%
WF_Star_Rating = fifa[fifa['W/F'] == 4]
WF_Star_Rating[['Name','Contract','Contract Status','Loan Date End','W/F']]
#pd.set_option('display.max_rows',3000)
# Out:
#                     Name     Contract Contract Status Loan Date End  W/F
# 0               L. Messi  2004 ~ 2021        Contract           NaN    4
# 1      Cristiano Ronaldo  2018 ~ 2022        Contract           NaN    4
# 5         R. Lewandowski  2014 ~ 2023        Contract           NaN    4
# 8              K. Mbappé  2018 ~ 2022        Contract           NaN    4
# 9          M. ter Stegen  2014 ~ 2022        Contract           NaN    4
# ...                  ...          ...             ...           ...  ...
# 18775         R. Fridolf  2020 ~ 2024        Contract           NaN    4
# 18779       Zhou Baizhao  2019 ~ 2021        Contract           NaN    4
# 18783    L. Schellenberg  2019 ~ 2022        Contract           NaN    4
# 18805      Lee Sung Yoon  2019 ~ 2024        Contract           NaN    4
# 18874        Y. Mosquera  2020 ~ 2024        Contract           NaN    4
#
# [2722 rows x 5 columns]

# %%
# HITS -- Players have been searched the most

fifa['Hits'].dtypes
# Out:
# dtype('O')

# %%
fifa['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %%
def convert_to_thousands(hits):
    if isinstance(hits, str) and 'K' in hits:
        return int(float(hits.replace('K', '')) * 1000)
    elif pd.isnull(hits):
        return 0
    else:
        return int(hits)

# Apply the function to the array

fifa['Hits'] = fifa['Hits'].apply(convert_to_thousands)

# %%
fifa['Hits'].sample(5)
# Out:
# 11776    2
# 3629     3
# 18526    0
# 15379    3
# 17952    0
# Name: Hits, dtype: int64

# %%
# finding top10 most searched

Player_Most_Searched = fifa[fifa['Hits'] >= 2000].head(10)
Player_Most_Searched[['Name','Contract','Contract Status','Hits']].sort_values(by = 'Hits', ascending = False).reset_index(drop = True)
# Out:
#               Name              Contract Contract Status  Hits
# 0      A. Tuanzebe           2013 ~ 2022        Contract  8400
# 1       D. Maldini           2018 ~ 2024        Contract  6000
# 2            Pedri           2020 ~ 2022        Contract  4300
# 3      M. Rashford           2014 ~ 2023        Contract  3200
# 4          Trincão           2020 ~ 2025        Contract  3000
# 5        Ansu Fati           2018 ~ 2022        Contract  2800
# 6      D. Sterling           2016 ~ 2022        Contract  2500
# 7      Alex Telles           2020 ~ 2024        Contract  2300
# 8  C. De Ketelaere           2018 ~ 2023        Contract  2300
# 9         Angeliño  Jun 30, 2021 On Loan         On Loan  2000

# %%
fifa.head(10)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# 5  188545     R. Lewandowski            Robert Lewandowski
# 6  209331           M. Salah                 Mohamed Salah
# 7  212831            Alisson         Alisson Ramses Becker
# 8  231747          K. Mbappé                 Kylian Mbappé
# 9  192448      M. ter Stegen         Marc-André ter Stegen
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# ...

# %%
fifa = fifa.drop(['photoUrl','playerUrl'], axis =1)

# %%
#Cleaning the Skill Move Rating Column

fifa['SM'].unique()
# Out:
# array(['4★', '5★', '1★', '2★', '3★'], dtype=object)

# %%
fifa['SM'] = fifa['SM'].str.strip('★')
fifa['SM'] = fifa['SM'].astype(int)

# %%
fifa.head(3)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
#
#    ↓OVA  POT             Club     Contract Contract Start Contract End  \
# 0    93   93     FC Barcelona  2004 ~ 2021           2004         2021
# 1    92   92         Juventus  2018 ~ 2022           2018         2022
# 2    91   93  Atlético Madrid  2014 ~ 2023           2014         2023
#
#    Contract Length(years) Contract Status   Positions  Height(cm)  Weight(kg)  \
# 0                    17.0        Contract  RW, ST, CF         170          72
# 1                     4.0        Contract      ST, LW         187          83
# 2                     9.0        Contract          GK         188          87
#
# ...

# %%
# Injury Resitance rating

fifa['IR'].unique()
# Out:
# array(['5 ★', '3 ★', '4 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['IR'] = fifa['IR'].str.split(' ').str.get(0)
fifa.head(3)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
#
#    ↓OVA  POT             Club     Contract Contract Start Contract End  \
# 0    93   93     FC Barcelona  2004 ~ 2021           2004         2021
# 1    92   92         Juventus  2018 ~ 2022           2018         2022
# 2    91   93  Atlético Madrid  2014 ~ 2023           2014         2023
#
#    Contract Length(years) Contract Status   Positions  Height(cm)  Weight(kg)  \
# 0                    17.0        Contract  RW, ST, CF         170          72
# 1                     4.0        Contract      ST, LW         187          83
# 2                     9.0        Contract          GK         188          87
#
# ...

# %%
fifa['IR'] = fifa['IR'].astype(int)

# %%
fifa.dtypes
# Out:
# ID                          int64
# Name                       object
# LongName                   object
# Nationality                object
# Age                         int64
# ↓OVA                        int64
# POT                         int64
# Club                       object
# Contract                   object
# Contract Start             object
# Contract End               object
# Contract Length(years)    float64
# Contract Status            object
# Positions                  object
# Height(cm)                  int64
# Weight(kg)                  int64
# Preferred Foot             object
# BOV                         int64
# Best Position              object
# Joined                     object
# Loan Date End              object
# Value                      object
# Wage                       object
# Release Clause             object
# Attacking                   int64
# Crossing                    int64
# Finishing                   int64
# ...

# %%
pd.set_option('display.max_rows',80)

# %%
# Value Column
fifa['Value'].unique()
# Out:
# array(['€103.5M', '€63M', '€120M', '€129M', '€132M', '€111M', '€120.5M',
#        '€102M', '€185.5M', '€110M', '€113M', '€90.5M', '€82M', '€17.5M',
#        '€83.5M', '€33.5M', '€114.5M', '€78M', '€103M', '€109M', '€92M',
#        '€10M', '€76.5M', '€89.5M', '€87.5M', '€79.5M', '€124M', '€114M',
#        '€95M', '€92.5M', '€105.5M', '€88.5M', '€85M', '€81.5M', '€26M',
#        '€21M', '€56M', '€67.5M', '€53M', '€36.5M', '€51M', '€65.5M',
#        '€46.5M', '€61.5M', '€72.5M', '€77.5M', '€43.5M', '€32.5M', '€36M',
#        '€32M', '€54M', '€49.5M', '€57M', '€66.5M', '€74.5M', '€71.5M',
#        '€121M', '€99M', '€67M', '€86.5M', '€93.5M', '€70M', '€62M',
#        '€66M', '€58M', '€44M', '€81M', '€37M', '€14.5M', '€46M', '€47.5M',
#        '€52.5M', '€54.5M', '€34.5M', '€57.5M', '€51.5M', '€44.5M', '€55M',
#        '€48M', '€60.5M', '€63.5M', '€61M', '€29M', '€58.5M', '€55.5M',
#        '€42M', '€40.5M', '€43M', '€45.5M', '€34M', '€26.5M', '€42.5M',
# ...

# %%
fifa['Value'].isnull().sum()
# Out:
# 0

# %%
fifa['Value'] = fifa['Value'].str.strip('€')
fifa['Value'].head(11)
# Out:
# 0     103.5M
# 1        63M
# 2       120M
# 3       129M
# 4       132M
# 5       111M
# 6     120.5M
# 7       102M
# 8     185.5M
# 9       110M
# 10      113M
# Name: Value, dtype: object

# %%
def convert_value(value):
    if 'M' in value:
        return int(float(value.strip('M'))*1000000)
    elif 'K' in value:
        return int(float(value.strip('K'))*1000)
    else:
        return int(value)

#Apply function into array

fifa['Value'] = fifa['Value'].apply(convert_value)

# %%
fifa.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                 Club     Contract Contract Start Contract End  \
# 0    93   93         FC Barcelona  2004 ~ 2021           2004         2021
# 1    92   92             Juventus  2018 ~ 2022           2018         2022
# 2    91   93      Atlético Madrid  2014 ~ 2023           2014         2023
# 3    91   91      Manchester City  2015 ~ 2023           2015         2023
# 4    91   91  Paris Saint-Germain  2017 ~ 2022           2017         2022
#
# ...

# %%
# Wage Column
fifa['Wage'].unique()
# Out:
# array(['€560K', '€220K', '€125K', '€370K', '€270K', '€240K', '€250K',
#        '€160K', '€260K', '€210K', '€310K', '€130K', '€350K', '€300K',
#        '€190K', '€145K', '€195K', '€100K', '€140K', '€290K', '€82K',
#        '€110K', '€230K', '€155K', '€200K', '€165K', '€95K', '€170K',
#        '€105K', '€115K', '€150K', '€135K', '€55K', '€58K', '€81K', '€34K',
#        '€120K', '€59K', '€90K', '€65K', '€56K', '€71K', '€18K', '€75K',
#        '€47K', '€20K', '€84K', '€86K', '€74K', '€78K', '€27K', '€68K',
#        '€85K', '€25K', '€46K', '€83K', '€54K', '€79K', '€175K', '€43K',
#        '€49K', '€45K', '€38K', '€41K', '€39K', '€23K', '€51K', '€50K',
#        '€87K', '€30K', '€14K', '€69K', '€31K', '€64K', '€53K', '€35K',
#        '€21K', '€28K', '€17K', '€33K', '€70K', '€32K', '€89K', '€26K',
#        '€40K', '€76K', '€72K', '€48K', '€36K', '€29K', '€60K', '€16K',
#        '€37K', '€24K', '€52K', '€0', '€62K', '€73K', '€63K', '€19K',
# ...

# %%
fifa['Wage'] = fifa['Wage'].str.split('€',expand = True)[1]
fifa['Wage']
# Out:
# 0        560K
# 1        220K
# 2        125K
# 3        370K
# 4        270K
#          ...
# 18974      1K
# 18975     500
# 18976     500
# 18977      2K
# 18978      1K
# Name: Wage, Length: 18979, dtype: object

# %%
fifa['Wage'] = fifa['Wage'].str.split('K').str.get(0).astype(int)

# %%
fifa['Wage'] = fifa['Wage'] * 1000

# %%
# Release Clause
#fifa['Release Clause'].unique()
fifa['Release Clause'] = fifa['Release Clause'].str.split('€',expand = True)[1]
fifa['Release Clause']
# Out:
# 0        138.4M
# 1         75.9M
# 2        159.4M
# 3          161M
# 4        166.5M
#           ...
# 18974       70K
# 18975      165K
# 18976      131K
# 18977       88K
# 18978       79K
# Name: Release Clause, Length: 18979, dtype: object

# %%
def converted_value(value):
    if 'M' in value:
        return round(int(float(value.strip('M'))*1000000))
    elif 'K' in value:
        return int(float(value.strip('K'))*1000)
    else:
        return int(value)

#Apply arrays to column

fifa['Release Clause'] = fifa['Release Clause'].apply(converted_value)

# %%
fifa['Release Clause'].unique()
# Out:
# array([138400000,  75900000, 159400000, ...,     59000,     35000,
#            64000], dtype=int64)

# %%
fifa.rename(columns = {'Wage':'Wage(€)', 'Value':'Value(€)', 'Release Clause':'Release Clause(€)'},inplace = True)

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'Nationality', 'Age', '↓OVA', 'POT', 'Club',
#        'Contract', 'Contract Start', 'Contract End', 'Contract Length(years)',
#        'Contract Status', 'Positions', 'Height(cm)', 'Weight(kg)',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value(€)', 'Wage(€)', 'Release Clause(€)', 'Attacking', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill',
#        'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
#        'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions',
#        'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning',
#        'Vision', 'Penalties', 'Composure', 'Defending', 'Marking',
#        'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
# ...

# %%
fifa.head(5)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                 Club     Contract Contract Start Contract End  \
# 0    93   93         FC Barcelona  2004 ~ 2021           2004         2021
# 1    92   92             Juventus  2018 ~ 2022           2018         2022
# 2    91   93      Atlético Madrid  2014 ~ 2023           2014         2023
# 3    91   91      Manchester City  2015 ~ 2023           2015         2023
# 4    91   91  Paris Saint-Germain  2017 ~ 2022           2017         2022
#
# ...

# %%
FIFA_21 = fifa

# %%
FIFA_21.to_excel('Cleaned_FIFA_21.xlsx', index = False)
